# %% [markdown]
# <a href="https://colab.research.google.com/github/sirliboyev-uz/computer-vision/blob/main/Subplot_NxM_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = False
plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = False
plt.rcParams['ytick.left'] = plt.rcParams['ytick.labelleft'] = False

# %%
def subplot_2x3(fig):
  """
  Draw axises two rows and three columns. 2x3
  Args:
    fig: figure
  Returns:
    axis: The Axes of the subplot.
  """

# %%
fig = plt.figure(figsize=(6,4))
ax2x3 = subplot_2x3(fig)

# %%
def subplot_4x2(fig):
  """
  Draw axises four rows and two columns. 4x2
  Args:
    fig: figure
  Returns:
    axis: The Axes of the subplot.
  """

# %%
fig = plt.figure(figsize=(4,8))
ax4x2 = subplot_4x2(fig)

# %%
def subplot_3x5(fig):
  """
  Draw axises three rows and five columns. 3x5
  Args:
    fig: figure
  Returns:
    axis: The Axes of the subplot.
  """

# %%
fig = plt.figure(figsize=(10,6))
ax3x5 = subplot_3x5(fig)

# %%
def subplot_5x5(fig):
  """
  Draw axises two rows and three columns. 5x5
  Args:
    fig: figure
  Returns:
    axis: The Axes of the subplot.
  """

# %%
fig = plt.figure(figsize=(10,10))
ax5x5 = subplot_5x5(fig)

# %%
def subplot_3x1(fig):
  """
  Draw axises two rows and three columns. 3x1
  Args:
    fig: figure
  Returns:
    axis: The Axes of the subplot.
  """

# %%
fig = plt.figure(figsize=(2,6))
ax3x1 = subplot_3x1(fig)

# %%
def subplot_1x3(fig):
  """
  Draw axises twoone row and three columns. 1x3
  Args:
    fig: figure
  Returns:
    axis: The Axes of the subplot.
  """

# %%
fig = plt.figure(figsize=(6,2))
ax3x1 = subplot_1x3(fig)

# %%
def subplot_NxM(fig,row:int,col:int):
  """
  Draw axises two rows and three columns. NxM
  Args:
    fig: figure
  Returns:
    axis: The Axes of the subplot.
  """

# %%
fig = plt.figure(figsize=(6,4))
ax2x3 = subplot_NxM(fig,2,3)

# %%
fig = plt.figure(figsize=(4,8))
ax4x2 = subplot_NxM(fig,4,2)
